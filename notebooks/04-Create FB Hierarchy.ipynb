# %%
semantic_hierarchy = {
                'Level-1': ['wordnet_person_100007846', 'wordnet_organization_108008335', 'wordnet_body_of_water_109225146', 'wordnet_product_104007894', 'wordnet_event_100029378'],

                'Level-2-event': ['wordnet_festival_100517728','wordnet_festival_115162388', 'wordnet_conference_108308497', 'wordnet_show_106619065', 
                                 'wordnet_show_100520257', 'wordnet_social_event_107288639'],

                'Level-2-organization': [ 'wordnet_party_108256968', "wordnet_world_organization_108294696", 'wordnet_musical_organization_108246613',
                                        'wordnet_enterprise_108056231', 'wordnet_nongovernmental_organization_108009834', 'wordnet_institution_108053576', 
                                        "wordnet_government_108050678"], 

                'Level-3-organization-institution':["wordnet_educational_institution_108276342", "wordnet_university_108286569","wordnet_financial_institution_108054721",
                                                   "wordnet_medical_institution_108053905", "wordnet_naval_academy_108279665", "wordnet_public_school_108410282",
                                                   "wordnet_academy_108277805","wordnet_nursing_school_108283757", "wordnet_law_school_108283051",
                                                   "wordnet_community_college_108282542", "wordnet_university_108286569", "wordnet_normal_school_108412620",
                                                  "wordnet_graduate_school_108282696"],

                'Level-3-organization-enterprise': ['wordnet_electronics_company_108003035', 'wordnet_insurance_company_108070465', "wordnet_corporation_108059412",
                                                   'wordnet_investment_company_108070850', 'wordnet_shipping_company_108003717', "wordnet_industry_108065234",
                                                   'wordnet_company_108058098','wordnet_electronics_company_108003035','wordnet_power_company_108186393',
                                                   'wordnet_telephone_company_108186221', 'wordnet_food_company_108003427','wordnet_subsidiary_company_108003935',
                                                   'wordnet_film_company_108003173', 'wordnet_holding_company_108185369','wordnet_broadcasting_company_108002015',
                                                   'wordnet_drug_company_108002578', "wordnet_commercial_enterprise_108065093", 'wordnet_motion-picture_film_103789400'],

                'Level-2-body_of_water': ['wordnet_stream_109448361', 'wordnet_lake_109328904', 'wordnet_ocean_109376198', 'wordnet_waterway_109476331',
                                         'wordnet_bay_109215664', 'wordnet_sea_109426788', 'wordnet_waterfall_109475292'],
    
                'Level-3-body_of_water-sea': ['wordnet_seaport_108639058', 'wordnet_seashore_109428293', 'wordnet_shore_109433442'],


                'Level-2-person': ['wordnet_officeholder_110371450', 'wordnet_writer_110794014', 'wordnet_writer_110801291', 'wordnet_man_110287213',
                                  'wordnet_scientist_110560637', 'wordnet_politician_110450303', 'wordnet_creator_109614315', 'wordnet_people_107942152',
                                  'wordnet_female_109619168', 'wordnet_woman_110787470', 'wordnet_good_person_110138767', 'wordnet_director_110014939',
                                  'wordnet_director_110015215', 'wordnet_politician_110451263', 'wordnet_lawyer_110249950','wordnet_artist_109812338' ,
                                  'wordnet_doctor_110020890', 'wordnet_player_110439851', 'wordnet_male_109624168'], 


                'Level-3-person-docktor':['wordnet_ear-nose-and-throat_doctor_110059323',  'wordnet_nurse_110366966', 'wordnet_psychiatrist_110488016', 
                                          'wordnet_neurologist_110354265'],

                'Level-3-person-writer': ['wordnet_poet_110444194', 'wordnet_novelist_110363573',  'wordnet_photojournalist_110427223',
                                         'wordnet_composer_109947232', 'wordnet_scriptwriter_110564905', 'wordnet_journalist_110224578',
                                         'wordnet_dramatist_110030277', 'wordnet_essayist_110064405', 'wordnet_biographer_109855433',
                                         'wordnet_sports_writer_110640084', 'wordnet_screenwriter_110564400', 'wordnet_scriptwriter_110564905',
                                         'wordnet_copywriter_109965021', 'wordnet_songwriter_110624540','wordnet_ghostwriter_110128748',
                                         'wordnet_speechwriter_110631654'], 

                'Level-3-person-scientist':[ 'wordnet_biologist_109855630','wordnet_physicist_110428004','wordnet_publisher_108062623', 'wordnet_social_scientist_110619642',
                                             'wordnet_mathematician_110301261', 'wordnet_chemist_109913824', 'wordnet_linguist_110264437', 'wordnet_scholar_110557854',
                                             'wordnet_psychologist_110488865', 'wordnet_geologist_110127689', 'wordnet_computer_scientist_109951070', 
                                             'wordnet_research_worker_110523076', 'wordnet_cognitive_scientist_109934647', "wordnet_social_anthropologist_110618465",
                                             'wordnet_paleontologist_110394786', 'wordnet_analyst_109790278', 'wordnet_aerospace_engineer_109776079', 
                                             'wordnet_engineer_109615807'], 

                'Level-3-person-player': ['wordnet_football_player_110101634','wordnet_ballplayer_109835506','wordnet_soccer_player_110618342',
                                          'wordnet_golfer_110136959', 'wordnet_tennis_player_110701180','wordnet_basketball_player_109842047',
                                          'wordnet_card_player_109894654','wordnet_most_valuable_player_110332257','wordnet_lacrosse_player_110242682',
                                          'wordnet_bridge_player_109875353','wordnet_hockey_player_110179291','wordnet_chess_player_109915834'],

                'Level-3-person-artist': ['wordnet_painter_110391653', 'wordnet_sculptor_110566072', 'wordnet_photographer_110426749',
                                          'wordnet_illustrator_109812068', 'wordnet_printmaker_110475687', 'wordnet_recorder_player_110512109',
                                          'wordnet_sitar_player_110603851', 'wordnet_actor_109767197', 'wordnet_tenor_saxophonist_110701962',
                                          'wordnet_lyricist_110277912', 'wordnet_folk_singer_110099093', 'wordnet_cameraman_109889539', 
                                          'wordnet_satirist_110552742', 'wordnet_performer_110415638', 'wordnet_actor_109765278']
               }

# %%
hierarchies = {}
count = 0
for level, wordnet_types in semantic_hierarchy.items():
    if level not in hierarchies:
        hierarchies[level] = []
    for wordnet_type in wordnet_types:
        if wordnet_type not in hierarchies[level]:
            count += 1
            hierarchies[level].append(wordnet_type)
            
print(f"Counts: before: 49 , now:{count}")
print("-"*100)

print(f"keys: {hierarchies.keys()}")
print("-"*100)

for key, items in hierarchies.items():
    print(key, "\t", len(items))
# Out:
# Counts: before: 49 , now:140
# ----------------------------------------------------------------------------------------------------
# keys: dict_keys(['Level-1', 'Level-2-event', 'Level-2-organization', 'Level-3-organization-institution', 'Level-3-organization-enterprise', 'Level-2-body_of_water', 'Level-3-body_of_water-sea', 'Level-2-person', 'Level-3-person-docktor', 'Level-3-person-writer', 'Level-3-person-scientist', 'Level-3-person-player', 'Level-3-person-artist'])
# ----------------------------------------------------------------------------------------------------
# Level-1 	 5
# Level-2-event 	 6
# Level-2-organization 	 7
# Level-3-organization-institution 	 12
# Level-3-organization-enterprise 	 17
# Level-2-body_of_water 	 7
# Level-3-body_of_water-sea 	 3
# Level-2-person 	 19
# Level-3-person-docktor 	 4
# Level-3-person-writer 	 15
# Level-3-person-scientist 	 18
# Level-3-person-player 	 12
# Level-3-person-artist 	 15

# %%
level1_mapper = {}

for level, wordnet_types in semantic_hierarchy.items():
    if level.startswith("Level-1"):        
        for wordnet_type in wordnet_types:
            level1_mapper[wordnet_type] = level + "@" + '_'.join(wordnet_type.split("_")[1:-1])

level1_mapper
# Out:
# {'wordnet_person_100007846': 'Level-1@person',
#  'wordnet_organization_108008335': 'Level-1@organization',
#  'wordnet_body_of_water_109225146': 'Level-1@body_of_water',
#  'wordnet_product_104007894': 'Level-1@product',
#  'wordnet_event_100029378': 'Level-1@event'}

# %%
level2_mapper = {}

for level, wordnet_types in semantic_hierarchy.items():
    if level.startswith("Level-2"):        
        for wordnet_type in wordnet_types:
            level2_mapper[wordnet_type] = level + "@" + '_'.join(wordnet_type.split("_")[1:-1])

level2_mapper
# Out:
# {'wordnet_festival_100517728': 'Level-2-event@festival',
#  'wordnet_festival_115162388': 'Level-2-event@festival',
#  'wordnet_conference_108308497': 'Level-2-event@conference',
#  'wordnet_show_106619065': 'Level-2-event@show',
#  'wordnet_show_100520257': 'Level-2-event@show',
#  'wordnet_social_event_107288639': 'Level-2-event@social_event',
#  'wordnet_party_108256968': 'Level-2-organization@party',
#  'wordnet_world_organization_108294696': 'Level-2-organization@world_organization',
#  'wordnet_musical_organization_108246613': 'Level-2-organization@musical_organization',
#  'wordnet_enterprise_108056231': 'Level-2-organization@enterprise',
#  'wordnet_nongovernmental_organization_108009834': 'Level-2-organization@nongovernmental_organization',
#  'wordnet_institution_108053576': 'Level-2-organization@institution',
#  'wordnet_government_108050678': 'Level-2-organization@government',
#  'wordnet_stream_109448361': 'Level-2-body_of_water@stream',
# ...

# %%
level3_mapper = {}

for level, wordnet_types in semantic_hierarchy.items():
    if level.startswith("Level-3"):        
        for wordnet_type in wordnet_types:
            level3_mapper[wordnet_type] = level + "@" + '_'.join(wordnet_type.split("_")[1:-1])

level3_mapper
# Out:
# {'wordnet_educational_institution_108276342': 'Level-3-organization-institution@educational_institution',
#  'wordnet_university_108286569': 'Level-3-organization-institution@university',
#  'wordnet_financial_institution_108054721': 'Level-3-organization-institution@financial_institution',
#  'wordnet_medical_institution_108053905': 'Level-3-organization-institution@medical_institution',
#  'wordnet_naval_academy_108279665': 'Level-3-organization-institution@naval_academy',
#  'wordnet_public_school_108410282': 'Level-3-organization-institution@public_school',
#  'wordnet_academy_108277805': 'Level-3-organization-institution@academy',
#  'wordnet_nursing_school_108283757': 'Level-3-organization-institution@nursing_school',
#  'wordnet_law_school_108283051': 'Level-3-organization-institution@law_school',
#  'wordnet_community_college_108282542': 'Level-3-organization-institution@community_college',
# ...

# %%
import json

semantic_hierarchy = {
    "level-1": level1_mapper,
    "level-2": level2_mapper,
    "level-3": level3_mapper
}

path = "../assets/FreeBase/"

with open(path+"freebase_llms2ol_hierarchy.json", "w") as js_file:
    js_file.write(json.dumps(semantic_hierarchy, indent=4))

# %%
wordnet_academician_109759069
